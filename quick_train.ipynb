# %% [markdown]
# # Quick training demo
# Run the scripts from the command line, or use the commands below.

# %%
# !python scripts/generate_synthetic.py
# !python scripts/train.py --epochs 3
# !python scripts/evaluate.py
